# %% [markdown]
# ## Problem Statement

# %% [markdown]
# A retail company wants to understand the customer purchase behaviour (specifically, purchase amount) against various products of different categories. They have shared purchase summary of various customers for selected high volume products from last month.
# The data set also contains customer demographics (age, gender, marital status, city_type, stay_in_current_city), product details (product_id and product category) and Total purchase_amount from last month.
#
# Now, they want to build a model to predict the purchase amount of customer against various products which will help them to create personalized offer for customers against different products.

# %% [markdown]
# ## Variable	Definition

# %%
# User_ID	User ID
# Product_ID	Product ID
# Gender	Sex of User
# Age	Age in bins
# Occupation	Occupation (Masked)
# City_Category	Category of the City (A,B,C)
# Stay_In_Current_City_Years	Number of years stay in current city
# Marital_Status	Marital Status
# Product_Category_1	Product Category (Masked)
# Product_Category_2	Product may belongs to other category also (Masked)
# Product_Category_3	Product may belongs to other category also (Masked)
# Purchase	Purchase Amount (Target Variable)

# %% [markdown]
# ## Importing Libraries and Loading data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("https://raw.githubusercontent.com/nanthasnk/Black-Friday-Sales-Prediction/master/Data/BlackFridaySales.csv")

# %%
data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
data.shape
# Out:
# (550068, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 50.4+ MB

# %% [markdown]
# `Age` should be treated as a numerical column
#
# `City_Category` we can convert this to a numerical column and should look at the frequency of each city category.
#
# `Gender` has two values and should be converted to binary values
#
# `Product_Category_2` and `Product_Category_3` have null values

# %% [markdown]
# ## Checking Null values

# %%
data.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %% [markdown]
# ## Null Value in percentage

# %%
data.isnull().sum()/data.shape[0]*100
# Out:
# User_ID                        0.000000
# Product_ID                     0.000000
# Gender                         0.000000
# Age                            0.000000
# Occupation                     0.000000
# City_Category                  0.000000
# Stay_In_Current_City_Years     0.000000
# Marital_Status                 0.000000
# Product_Category_1             0.000000
# Product_Category_2            31.566643
# Product_Category_3            69.672659
# Purchase                       0.000000
# dtype: float64

# %% [markdown]
# There are 31% null values in the `Product_Category_2` and 69% null values in the `Product_Category_3`

# %% [markdown]
# # Unique elements in each attributes

# %%
data.nunique()
# Out:
# User_ID                        5891
# Product_ID                     3631
# Gender                            2
# Age                               7
# Occupation                       21
# City_Category                     3
# Stay_In_Current_City_Years        5
# Marital_Status                    2
# Product_Category_1               20
# Product_Category_2               17
# Product_Category_3               15
# Purchase                      18105
# dtype: int64

# %% [markdown]
# We can drop `User_ID` and `Product_ID` for model prediction as it has more unique values.

# %% [markdown]
# # EDA

# %% [markdown]
# ## Target Variable Purchase

# %%
sns.distplot(data["Purchase"],color='r')
plt.title("Purchase Distribution")
plt.show()
# Out:
# C:\Users\Charitha\AppData\Local\Temp\ipykernel_19620\2016751557.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["Purchase"],color='r')

# %% [markdown]
# We can observe that purchase amount is repeating for many customers.This may be because on Black Friday many are buying discounted products in large numbers and kind of follows a Gaussian Distribution.

# %%
sns.boxplot(data["Purchase"])
plt.title("Boxplot of Purchase")
plt.show()

# %%
data["Purchase"].skew()
# Out:
# 0.6001400037087128

# %%
data["Purchase"].kurtosis()
# Out:
# -0.3383775655851702

# %%
data["Purchase"].describe()
# Out:
# count    550068.000000
# mean       9263.968713
# std        5023.065394
# min          12.000000
# 25%        5823.000000
# 50%        8047.000000
# 75%       12054.000000
# max       23961.000000
# Name: Purchase, dtype: float64

# %% [markdown]
# The purchase is right skewed and we can observe multiple peaks in the distribution we can do a log transformation for the purchase.

# %% [markdown]
# ### Gender

# %%
sns.countplot(x='Gender', data=data)
plt.show()

# %%
data['Gender'].value_counts(normalize=True)*100
# Out:
# Gender
# M    75.310507
# F    24.689493
# Name: proportion, dtype: float64

# %% [markdown]
# There are more males than females

# %%
result = data.groupby("Gender")["Purchase"].mean()

print(result)
# Out:
# Gender
# F    8734.565765
# M    9437.526040
# Name: Purchase, dtype: float64

# %% [markdown]
# On average the male gender spends more money on purchase contrary to female, and it is possible to also observe this trend by adding the total value of purchase.

# %% [markdown]
# ### Marital Status

# %%
sns.countplot(data['Marital_Status'])
plt.show()

# %% [markdown]
# There are more unmarried people in the dataset who purchase more

# %%
result = data.groupby("Marital_Status")["Purchase"].mean()

print(result)
# Out:
# Marital_Status
# 0    9265.907619
# 1    9261.174574
# Name: Purchase, dtype: float64

# %%
mean_purchase_by_marital_status = data.groupby("Marital_Status")["Purchase"].mean()
# Plot the results
mean_purchase_by_marital_status.plot(kind='bar')
plt.title("Marital Status and Purchase Analysis")
plt.xlabel("Marital Status")
plt.ylabel("Average Purchase")
plt.show()

# %% [markdown]
# This is interesting though unmarried people spend more on purchasing, the average purchase amount of married and unmarried people are the same.

# %% [markdown]
# ### Occupation

# %%
plt.figure(figsize=(18,5))
sns.countplot(data['Occupation'])
plt.show()

# %% [markdown]
# Occupation has at least 20 different values. Since we do not known to each occupation each number corresponds, is difficult to make any analysis. Furthermore, it seems we have no alternative but to use since there is no way to reduce this number

# %%
occup = pd.DataFrame(data.groupby("Occupation")["Purchase"].mean())

print(occup)
# Out:
#                Purchase
# Occupation
# 0           9124.428588
# 1           8953.193270
# 2           8952.481683
# 3           9178.593088
# 4           9213.980251
# 5           9333.149298
# 6           9256.535691
# 7           9425.728223
# 8           9532.592497
# 9           8637.743761
# 10          8959.355375
# 11          9213.845848
# 12          9796.640239
# 13          9306.351061
# 14          9500.702772
# 15          9778.891163
# 16          9394.464349
# 17          9821.478236
# 18          9169.655844
# 19          8710.627231
# 20          8836.494905

# %%
occup.plot(kind='bar',figsize=(15,5))
plt.title("Occupation and Purchase Analysis")
plt.show()

# %% [markdown]
# Although there are some occupations which have higher representations, it seems that the amount each user spends on average is more or less the same for all occupations. Of course, in the end, occupations with the highest representations will have the highest amounts of purchases.

# %% [markdown]
# ### City_Category

# %%
sns.countplot(data=data, x='City_Category')
plt.show()

# %% [markdown]
# It is observed that city category B has made the most number of puchases.

# %%
city_purchase = data.groupby("City_Category")["Purchase"].mean()

# Plot bar chart
city_purchase.plot(kind='bar')
plt.title("City Category and Purchase Analysis")
plt.xlabel("City Category")
plt.ylabel("Mean Purchase")
plt.show()

# %% [markdown]
# However, the city whose buyers spend the most is city type ‘C’.

# %% [markdown]
# ### Stay_In_Current_City_Years

# %%
sns.countplot(data=data, x='Stay_In_Current_City_Years')
plt.title('Distribution of Stay in Current City Years')
plt.xlabel('Years')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# It looks like the longest someone is living in that city the less prone they are to buy new things. Hence, if someone is new in town and needs a great number of new things for their house that they’ll take advantage of the low prices in Black Friday to purchase all the things needed.

# %%
mean_purchase = data.groupby("Stay_In_Current_City_Years")["Purchase"].mean()
# Plotting the bar chart
mean_purchase.plot(kind='bar')
plt.title("Stay_In_Current_City_Years and Purchase Analysis")
plt.xlabel("Stay_In_Current_City_Years")
plt.ylabel("Mean Purchase")
plt.show()

# %% [markdown]
# We see the same pattern seen before which show that on average people tend to spend the same amount on purchases regardeless of their group. People who are new in city are responsible for the higher number of purchase, however looking at it individually they tend to spend the same amount independently of how many years the have lived in their current city.

# %% [markdown]
# ### Age

# %%
sns.countplot(x='Age', data=data)
plt.title('Distribution of Age')
plt.xlabel('Different Categories of Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Age 26-35 Age group makes the most no of purchases in the age group.

# %%
age_purchase_mean = data.groupby('Age')['Purchase'].mean()

# Plot the mean 'Purchase' by 'Age'
age_purchase_mean.plot(kind='bar')
plt.title('Average Purchase Amount by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Average Purchase')
plt.show()

# %% [markdown]
# Mean puchase rate between the age groups tends to be the same except that the 51-55 age group has a little higher average purchase amount

# %%
data.groupby("Age").sum()['Purchase'].plot(kind="bar")
plt.title("Age and Purchase Analysis")
plt.show()

# %% [markdown]
# Total amount spent in purchase is in accordance with the number of purchases made, distributed by age.

# %% [markdown]
# ### Product_Category_1

# %%
plt.figure(figsize=(18,5))
sns.countplot(data['Product_Category_1'])
plt.show()

# %% [markdown]
# It is clear that `Product_Category_1` numbers 1,5 and 8 stand out. Unfortunately we don't know which product each number represents as it is masked.

# %%
category_purchase_mean = data.groupby('Product_Category_1')['Purchase'].mean()

# Plot the mean 'Purchase' by 'Product_Category_1'
category_purchase_mean.plot(kind='bar', figsize=(18, 5))
plt.title("Product Category 1 and Purchase Mean Analysis")
plt.xlabel('Product Category 1')
plt.ylabel('Average Purchase')
plt.show()

# %% [markdown]
# If you see the value spent on average for Product_Category_1 you see that although there were more products bought for categories 1,5,8 the average amount spent for those three is not the highest. It is interesting to see other categories appearing with high purchase values despite having low impact on sales number.

# %%
data.groupby('Product_Category_1').sum()['Purchase'].plot(kind='bar',figsize=(18,5))
plt.title("Product_Category_1 and Purchase Analysis")
plt.show()

# %% [markdown]
# The distribution that we saw for this predictor previously appears here. For example, those three products have the highest sum of sales since their were three most sold products.

# %% [markdown]
# ### Product_Category_2

# %%
plt.figure(figsize=(18,5))
sns.countplot(data['Product_Category_2'])
plt.show()

# %% [markdown]
# ### Product_Category_3

# %%
plt.figure(figsize=(18,5))
sns.countplot(data['Product_Category_3'])
plt.show()

# %%
# Filter numeric columns
numeric_data = data.select_dtypes(include=['int64', 'float64'])

# Compute correlation matrix
correlation_matrix = numeric_data.corr()

# Print correlation matrix
print("\nCorrelation Matrix:\n", correlation_matrix)
# Out:
# Correlation Matrix:
#                       User_ID  Occupation  Marital_Status  Product_Category_1  \
# User_ID             1.000000   -0.023971        0.020443            0.003825
# Occupation         -0.023971    1.000000        0.024280           -0.007618
# Marital_Status      0.020443    0.024280        1.000000            0.019888
# Product_Category_1  0.003825   -0.007618        0.019888            1.000000
# Product_Category_2  0.001529   -0.000384        0.015138            0.540583
# Product_Category_3  0.003419    0.013263        0.019473            0.229678
# Purchase            0.004716    0.020833       -0.000463           -0.343703
#
#                     Product_Category_2  Product_Category_3  Purchase
# User_ID                       0.001529            0.003419  0.004716
# Occupation                   -0.000384            0.013263  0.020833
# Marital_Status                0.015138            0.019473 -0.000463
# Product_Category_1            0.540583            0.229678 -0.343703
# Product_Category_2            1.000000            0.543649 -0.209918
# Product_Category_3            0.543649            1.000000 -0.022006
# Purchase                     -0.209918           -0.022006  1.000000

# %% [markdown]
# ## HeatMap

# %%
sns.heatmap(numeric_data.corr(),annot=True)
plt.show()

# %% [markdown]
# There is a some corellation between the product category groups.

# %%
data.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
df = data.copy()

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
# df['Stay_In_Current_City_Years'] = df['Stay_In_Current_City_Years'].replace(to_replace="4+",value="4")

# %%
#Dummy Variables:
df = pd.get_dummies(df, columns=['Stay_In_Current_City_Years'])

# %% [markdown]
# ## Encoding the categorical variables

# %%
from sklearn.preprocessing import LabelEncoder
lr = LabelEncoder()

# %%
df['Gender'] = lr.fit_transform(df['Gender'])

# %%
df['Age'] = lr.fit_transform(df['Age'])

# %%
df['City_Category'] = lr.fit_transform(df['City_Category'])

# %%
df.head()
# Out:
#    User_ID Product_ID  Gender  Age  Occupation  City_Category  Marital_Status  \
# 0  1000001  P00069042       0    0          10              0               0
# 1  1000001  P00248942       0    0          10              0               0
# 2  1000001  P00087842       0    0          10              0               0
# 3  1000001  P00085442       0    0          10              0               0
# 4  1000002  P00285442       1    6          16              2               0
#
#    Product_Category_1  Product_Category_2  Product_Category_3  Purchase  \
# 0                   3                 NaN                 NaN      8370
# 1                   1                 6.0                14.0     15200
# 2                  12                 NaN                 NaN      1422
# 3                  12                14.0                 NaN      1057
# 4                   8                 NaN                 NaN      7969
#
#    Stay_In_Current_City_Years_0  Stay_In_Current_City_Years_1  \
# 0                         False                         False
# 1                         False                         False
# 2                         False                         False
# 3                         False                         False
# 4                         False                         False
#
#    Stay_In_Current_City_Years_2  Stay_In_Current_City_Years_3  \
# 0                          True                         False
# 1                          True                         False
# 2                          True                         False
# 3                          True                         False
# 4                         False                         False
#
#    Stay_In_Current_City_Years_4+
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                           True

# %%
df['Product_Category_2'] =df['Product_Category_2'].fillna(0).astype('int64')
df['Product_Category_3'] =df['Product_Category_3'].fillna(0).astype('int64')

# %%
df.isnull().sum()
# Out:
# User_ID                          0
# Product_ID                       0
# Gender                           0
# Age                              0
# Occupation                       0
# City_Category                    0
# Marital_Status                   0
# Product_Category_1               0
# Product_Category_2               0
# Product_Category_3               0
# Purchase                         0
# Stay_In_Current_City_Years_0     0
# Stay_In_Current_City_Years_1     0
# Stay_In_Current_City_Years_2     0
# Stay_In_Current_City_Years_3     0
# Stay_In_Current_City_Years_4+    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   User_ID                        550068 non-null  int64
#  1   Product_ID                     550068 non-null  object
#  2   Gender                         550068 non-null  int32
#  3   Age                            550068 non-null  int32
#  4   Occupation                     550068 non-null  int64
#  5   City_Category                  550068 non-null  int32
#  6   Marital_Status                 550068 non-null  int64
#  7   Product_Category_1             550068 non-null  int64
#  8   Product_Category_2             550068 non-null  int64
#  9   Product_Category_3             550068 non-null  int64
#  10  Purchase                       550068 non-null  int64
#  11  Stay_In_Current_City_Years_0   550068 non-null  bool
#  12  Stay_In_Current_City_Years_1   550068 non-null  bool
#  13  Stay_In_Current_City_Years_2   550068 non-null  bool
#  14  Stay_In_Current_City_Years_3   550068 non-null  bool
#  15  Stay_In_Current_City_Years_4+  550068 non-null  bool
# dtypes: bool(5), int32(3), int64(7), object(1)
# memory usage: 42.5+ MB

# %% [markdown]
# ## Dropping the irrelevant columns

# %%
df = pd.DataFrame(data)

# Print current columns
print("Current columns in DataFrame:", df.columns)

# Ensure 'User_ID' and 'Product_ID' exist
if 'User_ID' in df.columns and 'Product_ID' in df.columns:
    df = df.drop(['User_ID', 'Product_ID'], axis=1)
else:
    print("One or both columns 'User_ID' and 'Product_ID' not found in the DataFrame.")

# Print the DataFrame to verify
print("\nDataFrame after dropping columns:\n", df)
# Out:
# Current columns in DataFrame: Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')
#
# DataFrame after dropping columns:
#         Gender    Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0           F   0-17          10             A                          2
# 1           F   0-17          10             A                          2
# 2           F   0-17          10             A                          2
# 3           F   0-17          10             A                          2
# 4           M    55+          16             C                         4+
# ...       ...    ...         ...           ...                        ...
# 550063      M  51-55          13             B                          1
# 550064      F  26-35           1             C                          3
# 550065      F  26-35          15             B                         4+
# 550066      F    55+           1             C                          2
# 550067      F  46-50           0             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# 0                    0                   3                 NaN
# 1                    0                   1                 6.0
# 2                    0                  12                 NaN
# 3                    0                  12                14.0
# 4                    0                   8                 NaN
# ...                ...                 ...                 ...
# 550063               1                  20                 NaN
# 550064               0                  20                 NaN
# 550065               1                  20                 NaN
# 550066               0                  20                 NaN
# 550067               1                  20                 NaN
#
#         Product_Category_3  Purchase
# 0                      NaN      8370
# 1                     14.0     15200
# 2                      NaN      1422
# 3                      NaN      1057
# 4                      NaN      7969
# ...                    ...       ...
# 550063                 NaN       368
# 550064                 NaN       371
# 550065                 NaN       137
# 550066                 NaN       365
# 550067                 NaN       490
#
# [550068 rows x 10 columns]

# %% [markdown]
# ## Splitting data into independent and dependent variables

# %%
X = df.drop("Purchase",axis=1)

# %%
y=df['Purchase']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

# %% [markdown]
# ## Modeling

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder

# %%
encoder = OneHotEncoder()
X_train_encoded = encoder.fit_transform(X_train)

# %%
encoder = OneHotEncoder()
X_train_encoded = encoder.fit_transform(X_train)

# %%
lr = LinearRegression()
lr.fit(X_train_encoded, y_train)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# 9202.918677028278

# %%
lr.coef_
# Out:
# array([ 2.75740269e+01, -2.75740269e+01, -5.47669664e+01, -2.04024902e+02,
#        -1.18510621e+02, -1.44949838e+01,  1.81929154e+01,  2.47107307e+02,
#         1.26497251e+02, -6.80450874e+01, -9.83399835e+01, -9.84283242e+00,
#         1.88916802e+02,  8.34397457e+01,  1.84183337e+01,  1.28383778e+02,
#         4.58640445e+01, -3.42234637e+02,  5.12069473e+00, -1.35861196e+02,
#         5.33959189e+01,  2.21403358e+02,  2.50848791e+01,  1.10280630e+02,
#         2.78478971e+02,  2.51512800e+01,  1.19186848e+02, -1.14232697e+02,
#        -3.82827354e+02, -1.51741495e+02, -2.16994115e+02, -9.62500578e+01,
#         3.13244172e+02, -4.22529471e+00, -9.49135698e+00,  2.39481346e+01,
#        -7.63332558e+00, -2.59815739e+00,  3.11437655e+01, -3.11437655e+01,
#         4.33210299e+03,  2.60334140e+03,  2.11609312e+03, -6.58394893e+03,
#        -2.92437693e+03,  6.49605025e+03,  7.29127581e+03, -1.65218286e+03,
#         6.38502404e+03,  1.05270549e+04, -4.38362489e+03, -7.80927446e+03,
#        -8.43531084e+03,  4.03678040e+03,  5.50215945e+03,  5.70191642e+03,
#         1.01656448e+03, -6.17375853e+03, -9.19684145e+03, -8.84904432e+03,
#        -2.91189766e+00,  1.40474037e+03, -1.72667652e+03, -7.36179415e+02,
#        -1.35167371e+00,  6.74952276e+02,  1.96176313e+02, -2.47860104e+02,
#         1.30229835e+03, -3.75992660e+02, -5.29325939e+02, -2.70408548e+02,
#        -2.59168661e+02, -2.47266121e+02, -4.91468711e+01,  4.40375792e+02,
#         5.56356850e+02, -1.28611550e+02,  5.50647875e+02, -3.52624864e+03,
#         6.18844595e+02,  1.67501264e+02,  1.72828291e+03,  4.42697932e+02,
#        -7.92324062e+02, -4.25034289e+02,  4.16124590e+02, -6.67367751e+02,
#         2.04225906e+02, -3.27705336e+02,  1.68807237e+02,  1.11507238e+03,
#         2.44821858e+02,  8.16535324e+01])

# %%
X_test_encoded = encoder.transform(X_test)

y_pred = lr.predict(X_test_encoded)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 2251.15575877294

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 8881634.70775416

# %%
r2_score(y_test, y_pred)
# Out:
# 0.6479902549489269

# %%
from math import sqrt
print("RMSE of Linear Regression Model is ",sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# RMSE of Linear Regression Model is  2980.207158530118

# %% [markdown]
# # DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
import numpy as np
from math import sqrt

# %%
# Identify categorical columns
categorical_columns = X_train.select_dtypes(include=['object']).columns

# Define a preprocessor for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', SimpleImputer(strategy='mean'), X_train.select_dtypes(include=['number']).columns),
        ('cat', Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('onehot', OneHotEncoder(handle_unknown='ignore'))
        ]), categorical_columns)
    ])

# Fit and transform the training data
X_train_encoded = preprocessor.fit_transform(X_train)
X_test_encoded = preprocessor.transform(X_test)

# %%
# Create a regressor object
regressor = DecisionTreeRegressor(random_state=0)

# Fit the regressor on the preprocessed training data
regressor.fit(X_train_encoded, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
# Make predictions on the preprocessed test set
dt_y_pred = regressor.predict(X_test_encoded)

# %%
 mean_absolute_error(y_test, dt_y_pred)
# Out:
# 2373.2791597726446

# %%
mean_squared_error(y_test, dt_y_pred)
# Out:
# 11296101.778118206

# %%
r2_score(y_test, dt_y_pred)
# Out:
# 0.5522966168024452

# %%
from math import sqrt
print("RMSE of Linear Regression Model is ",sqrt(mean_squared_error(y_test, dt_y_pred)))
# Out:
# RMSE of Linear Regression Model is  3360.9673872440662

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
import numpy as np
from math import sqrt

# %%
# Identify categorical columns
categorical_columns = X_train.select_dtypes(include=['object']).columns

# Define a preprocessor for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', SimpleImputer(strategy='mean'), X_train.select_dtypes(include=['number']).columns),
        ('cat', Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('onehot', OneHotEncoder(handle_unknown='ignore'))
        ]), categorical_columns)
    ])

# Fit and transform the training data
X_train_encoded = preprocessor.fit_transform(X_train)
X_test_encoded = preprocessor.transform(X_test)

# %%
# Create a RandomForest regressor object
RFregressor = RandomForestRegressor(random_state=0, n_jobs=-1)

# Fit the regressor on the preprocessed training data
RFregressor.fit(X_train_encoded, y_train)
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=0)

# %%
# Make predictions on the preprocessed test set
rf_y_pred = RFregressor.predict(X_test_encoded)

# %%
mean_absolute_error(y_test, rf_y_pred)
# Out:
# 2219.9872714612757

# %%
mean_squared_error(y_test, rf_y_pred)
# Out:
# 9293519.135072846

# %%
r2_score(y_test, rf_y_pred)
# Out:
# 0.6316658578056424

# %%
from math import sqrt
print("RMSE of Linear Regression Model is ",sqrt(mean_squared_error(y_test, rf_y_pred)))
# Out:
# RMSE of Linear Regression Model is  3048.52737154726

# %% [markdown]
# # XGBoost Regressor

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from math import sqrt

# %%
# Identify categorical columns
categorical_columns = X_train.select_dtypes(include=['object']).columns

# Define a preprocessor for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', SimpleImputer(strategy='mean'), X_train.select_dtypes(include=['number']).columns),
        ('cat', Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('onehot', OneHotEncoder(handle_unknown='ignore'))
        ]), categorical_columns)
    ])

# Fit and transform the training data
X_train_encoded = preprocessor.fit_transform(X_train)
X_test_encoded = preprocessor.transform(X_test)

# %%
# Create an XGBRegressor object
xgb_reg = XGBRegressor(learning_rate=1.0, max_depth=6, min_child_weight=40, random_state=0)

# Fit the regressor on the preprocessed training data
xgb_reg.fit(X_train_encoded, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=1.0, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=40, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=0, ...)

# %%
# Make predictions on the preprocessed test set
xgb_y_pred = xgb_reg.predict(X_test_encoded)

# %%
mean_absolute_error(y_test, xgb_y_pred)
# Out:
# 2141.426510217603

# %%
mean_squared_error(y_test, xgb_y_pred)
# Out:
# 8240204.634154284

# %%
r2_score(y_test, xgb_y_pred)
# Out:
# 0.6734123359177442

# %%
from math import sqrt
print("RMSE of Linear Regression Model is ",sqrt(mean_squared_error(y_test, xgb_y_pred)))
# Out:
# RMSE of Linear Regression Model is  2870.5756625029558

# %% [markdown]
# The ML algorithm that perform the best was XGBoost Regressor Model with RMSE = 2870
